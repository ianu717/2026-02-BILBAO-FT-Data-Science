# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

#pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"
df = pd.read_csv(url, sep=",")
df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro12 = pd.DataFrame(df)
euro12.columns = (
    df.columns
        .str.replace(r'[%().]', '', regex=True)
        .str.replace('-', '_')
        .str.strip()
        .str.replace(' ', '_')
        .str.lower()
)
euro12.columns
# Out:
# Index(['team', 'goals', 'shots_on_target', 'shots_off_target',
#        'shooting_accuracy', 'goals_to_shots', 'total_shots_inc_blocked',
#        'hit_woodwork', 'penalty_goals', 'penalties_not_scored', 'headed_goals',
#        'passes', 'passes_completed', 'passing_accuracy', 'touches', 'crosses',
#        'dribbles', 'corners_taken', 'tackles', 'clearances', 'interceptions',
#        'clearances_off_line', 'clean_sheets', 'blocks', 'goals_conceded',
#        'saves_made', 'saves_to_shots_ratio', 'fouls_won', 'fouls_conceded',
#        'offsides', 'yellow_cards', 'red_cards', 'subs_on', 'subs_off',
#        'players_used'],
#       dtype='str')

# %%
euro12.index = euro12["team"]
euro12 = euro12.drop("team", axis=1)

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12["goals"]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: goals, dtype: int64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
euro12["team"].nunique()
# Out:
# 16

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12[["team","yellow_cards","red_cards"]]
discipline
# Out:
#                    team  yellow_cards  red_cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values("red_cards", ascending=False)
# Out:
#                    team  yellow_cards  red_cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 0               Croatia             9          0
# 3               England             5          0
# 4                France             6          0
# 2               Denmark             4          0
# 1        Czech Republic             7          0
# 7                 Italy            16          0
# 5               Germany             4          0
# 8           Netherlands             5          0
# 10             Portugal            12          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
discipline.sort_values("yellow_cards", ascending=False)
# Out:
#                    team  yellow_cards  red_cards
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 6                Greece             9          1
# 14               Sweden             7          0
# 9                Poland             7          1
# 1        Czech Republic             7          0
# 12               Russia             6          0
# 11  Republic of Ireland             6          1
# 4                France             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 5               Germany             4          0
# 2               Denmark             4          0

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
discipline["yellow_cards"].mean()
# Out:
# np.float64(7.4375)

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12.loc[(euro12["goals"] > 6), ["goals"]]
# Out:
#          goals
# team
# Germany     10
# Spain       12

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
euro12.index[euro12.index.str.startswith("G")].tolist()
# Out:
# ['Germany', 'Greece']

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
euro12.iloc[:, :7]
# Out:
#                      goals  shots_on_target  shots_off_target  \
# team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
euro12.iloc[:, :-3]
# Out:
#                      goals  shots_on_target  shots_off_target  \
# team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[["England", "Italy", "Russia"],["shooting_accuracy"]]
# Out:
#         shooting_accuracy
# team
# England             50.0%
# Italy               43.0%
# Russia              22.5%
