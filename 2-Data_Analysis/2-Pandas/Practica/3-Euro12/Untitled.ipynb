# %%
import pandas as pd
from diagnostico_inicial import diagnostico_inicial

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")
diagnostico_inicial(df)
# Out:
# ...
# 📊  EXPLORACIÓN INICIAL
# ...
#
# 🔷 Dimensiones: 193 filas × 6 columnas
#
# 🔷 Columnas: ['country', 'beer_servings', 'spirit_servings', 'wine_servings', 'total_litres_of_pure_alcohol', 'continent']
#
# 🔷 Tipos de datos:
# country                             str
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                           str
# dtype: object
#
# 🔷 Primeras 5 filas:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# ...
