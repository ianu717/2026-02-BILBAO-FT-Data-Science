# %% [markdown]
# # Buenas practicas antes de empezar a trabajar

# %% [markdown]
# ## 1. Importacion de librerias

# %%
import pandas as pd

# %% [markdown]
# ## 2. Exploracion inicial de los datos

# %% [markdown]
# - ### Declaracion del datarame

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv"
df = pd.read_csv(url, sep=",")

# %% [markdown]
# - ### Ver las primeras y ultimas filas

# %%
df

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# - ### Dimensiones del data frame

# %%
df.shape

# %% [markdown]
# - ### Nombres de las columnas

# %%
df.columns.tolist()

# %% [markdown]
# - ### Tipos de dato por columnas

# %%
df.dtypes

# %% [markdown]
# - ### Resumen general

# %%
df.info()

# %% [markdown]
# - ### Estadisticas descriptivas

# %%
df.describe()

# %%
df.describe(include="all")  # Incluye columnas no numéricas

# %% [markdown]
# ## 3. Verificar y manejar nulos

# %% [markdown]
# - ### Cantidad de valores nulos por columna

# %%
df.isnull().sum()

# %% [markdown]
# - ### Porcentaje de nulos

# %%
(df.isnull().sum() / len(df)) * 100

# %% [markdown]
# - ### Visualizar filas con nulos

# %%
df[df.isnull().any(axis=1)]

# %% [markdown]
# ## 3. Verificar duplicados

# %% [markdown]
# - ### Cantidad de filas duplicadas
