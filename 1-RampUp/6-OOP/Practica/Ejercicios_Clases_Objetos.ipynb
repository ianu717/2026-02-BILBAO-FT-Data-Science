# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomésticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas últimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un número con todas las ventas.
# * Método que calcula la media de ventas de los últimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
    """Clase con logica de negocio de una tienda"""
    
    def __init__(self, nombre: str, direccion: str, num_empleados: int, ventas: list[int]):
        self.tipo = "Electrodomesticos"
        self.abierta = True
        self.nombre = nombre
        self.direccion = direccion
        self.num_empleados = num_empleados
        self.ventas = ventas
        
    def get_ventas_totales(self):
        return sum(self.ventas)
        
    def get_media_ventas_empleado(self):
        return self.get_ventas_totales() / self.num_empleados

    def get_nombre_direccion(self):
        return f"{self.nombre} - {self.direccion}"

    def get_proyeccion_ventas(self, dinero_invertido: int):
        self.ventas = [venta * 1.25 if dinero_invertido < 1000 else venta * 1.5 for venta in self.ventas]
        return self.get_ventas_totales()

# %%
tienda1 = Tienda("NombreTienda1", "Direccion1", 10, [34, 56, 12])
tienda2 = Tienda("NombreTienda2", "Avenida Direccion2", 20, [54, 76, 92])
tienda3 = Tienda("NombreTienda3", "Direccion3 Avenida", 30, [44, 66, 72])

tiendas = [tienda1, tienda2, tienda3]
ventas_ultimo_mes = 0

for tienda in tiendas:
    print(f"Tienda: {tienda.nombre}")
    print(f"Ventas totales: {tienda.get_ventas_totales()}")
    print(f"Media de ventas por empleado: {tienda.get_media_ventas_empleado()}")
    print(f"Nombre con direccion: {tienda.get_nombre_direccion()}")
    ventas_ultimo_mes += tienda.ventas[len(tienda.ventas) - 1]
    print(f"Proyeccion de ventas con dinero < 1000: {tienda.get_proyeccion_ventas(500)} - {tienda.ventas}")
    print(f"Proyeccion de ventas con dinero >= 1000: {tienda.get_proyeccion_ventas(1000)} - {tienda.ventas}")
    if tienda.direccion.count("Avenida"):
        print(f"La tienda {tienda.nombre} es una Avenida")
    print()

print(f"Suma de ventas del ultimo mes de todas las tiendas: {ventas_ultimo_mes}")
# Out:
# Tienda: NombreTienda1
# Ventas totales: 102
# Media de ventas por empleado: 10.2
# Nombre con direccion: NombreTienda1 - Direccion1
# Proyeccion de ventas con dinero < 1000: 127.5 - [42.5, 70.0, 15.0]
# Proyeccion de ventas con dinero >= 1000: 191.25 - [63.75, 105.0, 22.5]
#
# Tienda: NombreTienda2
# Ventas totales: 222
# Media de ventas por empleado: 11.1
# Nombre con direccion: NombreTienda2 - Avenida Direccion2
# Proyeccion de ventas con dinero < 1000: 277.5 - [67.5, 95.0, 115.0]
# Proyeccion de ventas con dinero >= 1000: 416.25 - [101.25, 142.5, 172.5]
# La tienda NombreTienda2 es una Avenida
#
# Tienda: NombreTienda3
# Ventas totales: 182
# Media de ventas por empleado: 6.066666666666666
# Nombre con direccion: NombreTienda3 - Direccion3 Avenida
# Proyeccion de ventas con dinero < 1000: 227.5 - [55.0, 82.5, 90.0]
# Proyeccion de ventas con dinero >= 1000: 341.25 - [82.5, 123.75, 135.0]
# La tienda NombreTienda3 es una Avenida
#
# ...

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    """Clase Perro con cosas"""
    
    def __init__(self, raza: str, color_pelo = "Marron", duenio = False):
        self.patas = 4
        self.orejas = 2
        self.ojos = 2
        self.velocidad = 0
        self.raza = raza
        self.color_pelo = color_pelo
        self.duenio = duenio

    def andar(self, velocidad):
        self.velocidad += velocidad
        
    def parar(self):
        self.velocidad = 0

    def ladrar(arg):
        return f"¡GUAU! {arg}"

# %%
perro = Perro("Raza")

for atributo, valor in perro.__dict__.items():
    print(f"{atributo.title()}: {valor}")

print()
print("El perro empieza a andar...")
perro.andar(2)
perro.andar(3)
print(f"El perro va a una velocidad de {perro.velocidad}")

print()
print("Parando al perro...")
perro.parar()
print(f"El perro va a una velocidad de {perro.velocidad}")
# Out:
# Patas: 4
# Orejas: 2
# Ojos: 2
# Velocidad: 0
# Raza: Raza
# Color_Pelo: Marron
# Duenio: False
#
# El perro empieza a andar...
# El perro va a una velocidad de 5
#
# Parando al perro...
# El perro va a una velocidad de 0
