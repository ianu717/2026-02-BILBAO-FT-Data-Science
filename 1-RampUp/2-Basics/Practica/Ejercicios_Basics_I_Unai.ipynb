# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print(""" 
¿Por qué esta magnífica tecnlología científica
        que ahorra trabajo y nos hace la vida mas fácil,
                nos aporta tan poca felicidad?
                    La respuesta es esta, simplemente: porque aun no hemos aprendido a usarla con tino.
"Albert Einstein"
""")
# Out:
#
# ¿Por qué esta magnífica tecnlología científica
#         que ahorra trabajo y nos hace la vida mas fácil,
#                 nos aporta tan poca felicidad?
#                     La respuesta es esta, simplemente: porque aun no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
calle = "Mi calle"
numero = 3
ciudad = "Bilbao"
cod_postal = 48001
direccion = f"{ciudad}, {calle}, {numero}º, {cod_postal}"
print(direccion)
# Out:
# Bilbao, Mi calle, 3º, 48001

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
calle = input("Introduce la calle:")
numero = input("Introduce el numero:")
ciudad = input("Introduce la ciudad:")
cod_postal = input("Introduce el código postal:")
direccion = f"Tu dirección es: {ciudad}, {calle}, {numero}º, {cod_postal}"
print(direccion)

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %% [markdown]
# 1. Bien
# 2. Faltan las comillas de cierre del string
# 3. No se puede usar una palabra clave como nombre de variable
# 4. No se pueden usar espacios
# 5. No se puede usar una palabra clave como nombre de variable
# 6. No esta permitido empezar con un número
# 7. Bien

# %%
mi_variable = "Economía"
otra_var = "Ejercicio
True = "Ejercicio"
mi variab1e = "Alpha"
import = 40
81mi_variable = "Agua"
mi_variable10 = 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
celsius = float(input("Introduce la temperatura (°C):").replace(",", "."))
farenheit = celsius * (9/5) + 32
print(f"{celsius} °C = {farenheit} °F")
# Out:
# Introduce la temperatura (°C): 23,7
# 23.7 °C = 74.66 °F

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
"""
Conversor de 
celsius a 
farenheit
"""
celsius = float(input("Introduce la temperatura (°C):").replace(",", ".")) #introducir la temperatura en celsius
farenheit = celsius * (9/5) + 32 #Realizamos la conversion
print(f"{celsius} °C = {farenheit} °F") #Imprimimos el resultado por pantalla con formato
# Out:
# Introduce la temperatura (°C): 2442424524
# 2442424524.0 °C = 4396364175.2 °F
